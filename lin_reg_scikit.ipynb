# %% [markdown]
# # Linear Regression with Scikit
#
# This whole time I thought I was avoiding the hype train by focusing specifically on ML and ignoring the bigger AI bs. Turns out, I was wrong! My TensorFlow applications and code translations, while an incredible foundation for future highly complex endeavors, is incredibly overkill for linear regression. I did notice that the results in the coding lab were better, simpler, and even ran faster than my TensorFlow application, but I just assumed I needed to fine tune the model. Turns out... linear regression is far easier to implement than I ever thought.
#
# Given what I've accomplished thus far, this is gonna be a breeze. **Let's do this the right way now**.
